# %% [markdown]
# # Wine quality analysis
#
#
# #### We binarize the target and use binary classification techniques to predict the quality of the wine.
#
# #### We compare different classifiers and different features performances

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from tqdm import tqdm

from sklearn import datasets, linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error, r2_score

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import shuffle
import seaborn as sns
import imblearn
from imblearn.over_sampling import SMOTE


from vars import colors

from evaluate import plot_roc_pr_curves, evaluate_cls
from preprocessing import create_sets, remove_outlier
from functional import add_cls_res
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Import the data
# We have run previous analysis on red wine on 01 notebook. Now, we'll run our analysis on **red** wines.
#
# (But..) feel free to use the full methodology:
# - on red wine only
# - on both wines with color as a feature.

# %%
# Target color
tgt_wine = 'red'
# Threshold good wine/ bad wine
th = 7

rslt_col = ['method', 'dataset', 'pr_m', 'rec_m', 'f1_m', 'pr_w', 'rec_w', 'f1_w', 'auc', 'pr']
results_df = pd.DataFrame(columns=rslt_col)

# Open files
wine_path = f'__data__/winequality-{tgt_wine}.csv'
wine_df = pd.read_csv(wine_path, delimiter=';')

# Process column name
wine_df = wine_df.rename(columns=lambda x: x.replace(' ', '_'))

display(wine_df.head())
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# # Overview of the data statistics
#
# ▶ There are no missing values.
#
# ▶ All features are quantitative. Some predictors seems to have outliers (maximum >> Q75).
#
# ▶ There are 240 duplicated row. We keep them because it might me different wine tester.

# %%
# Count total NaN at each column in a DataFrame 
print(" \nCount total NaN at each column in white wine DataFrame : \n\n", 
      wine_df.isnull().sum())

# Duplicata
duplicata_per = 100*wine_df.duplicated().sum()/len(wine_df)
print(f' Number of duplicated rows: {duplicata_per:.2f}')

display(wine_df[wine_df.duplicated(keep=False)].head().sort_values(by='chlorides'))
# Out:
#
# Count total NaN at each column in white wine DataFrame :
#
#  fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
#  Number of duplicated rows: 15.01
#     fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 9             7.5              0.50         0.36             6.1      0.071
# 11            7.5              0.50         0.36             6.1      0.071
# 0             7.4              0.70         0.00             1.9      0.076
# 4             7.4              0.70         0.00             1.9      0.076
# 22            7.9              0.43         0.21             1.6      0.106
#
#     free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 22                 10.0                  37.0   0.9966  3.17       0.91
#
#     alcohol  quality
# 9      10.5        5
# 11     10.5        5
# 0       9.4        5
# 4       9.4        5
# 22      9.5        5

# %%
# Main statistics
display(wine_df.describe().round(2))
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count        1599.00           1599.00      1599.00         1599.00
# mean            8.32              0.53         0.27            2.54
# std             1.74              0.18         0.19            1.41
# min             4.60              0.12         0.00            0.90
# 25%             7.10              0.39         0.09            1.90
# 50%             7.90              0.52         0.26            2.20
# 75%             9.20              0.64         0.42            2.60
# max            15.90              1.58         1.00           15.50
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density       pH  \
# count    1599.00              1599.00               1599.00  1599.00  1599.00
# mean        0.09                15.87                 46.47     1.00     3.31
# std         0.05                10.46                 32.90     0.00     0.15
# min         0.01                 1.00                  6.00     0.99     2.74
# 25%         0.07                 7.00                 22.00     1.00     3.21
# 50%         0.08                14.00                 38.00     1.00     3.31
# 75%         0.09                21.00                 62.00     1.00     3.40
# max         0.61                72.00                289.00     1.00     4.01
#
#        sulphates  alcohol  quality
# count    1599.00  1599.00  1599.00
# mean        0.66    10.42     5.64
# std         0.17     1.07     0.81
# min         0.33     8.40     3.00
# 25%         0.55     9.50     5.00
# 50%         0.62    10.20     6.00
# 75%         0.73    11.10     6.00
# max         2.00    14.90     8.00

# %% [markdown]
# # Distribution of the target
# The target distribution seems normal (but we could double check it with tests such as Shapiro).
#
# ▶ Very low and high quality wines are rare.

# %%
# Distribution of the target
sns.catplot(x='quality', data=wine_df, kind='count', color='b')

# %% [markdown]
# # Binarize
# We use a threshold t=7 to binarize the data.
#
# The resulting class repartition is still unbalanced.

# %%
wine_df.quality = [1 if x >= th else 0 for x in wine_df.quality]

# Binary distribution of the target
sns.catplot(x='quality', data=wine_df, kind='count', color='b')

# %% [markdown]
# # Baseline
# For red wines, the most frequent class (86% of the dataset) is 6.
#
# We consider that a dummy classifier performance (predict all red wine as class 6) would have a average accuracy of 86%.

# %%
print(wine_df['quality'].value_counts(normalize=True, dropna=False).round(3) * 100)
# Out:
# 0    86.4
# 1    13.6
# Name: quality, dtype: float64

# %% [markdown]
# # Visualization of the correlation
#
# We want to visualize **pair-wise correlations** of the different features, and the **strenght of the correlation**.
#
#
# We use a **scatterplot** for visualize the correlations and the **correlation matrix** (standardized covariance matrice) to quantify them.
#
# ▶ We can observe:
#
# - Scatterplot:
#     - Linear relationship between the target (_quality_) and some parameters (_density, pH, sulfate and fixed acidity_).
# - Correlation matrix:
#     - Multicollinearity between features (alchohol/ density or density/fixed acidity).
#
# ▶  Relationships between features seem stronger with red than white wines.

# %%
sns.set(font_scale=1.5) 

sns.pairplot(wine_df)
plt.show()

# %% [markdown]
# # Correlation
#
#
# The highly correlated variable contributing the less for quality are:
# - residual sugar
# - fixed acidity
#
# We remind them for later feature selection.

# %%
sns.set(font_scale=1) 

# Making the result reproducible
RANDOM_STATE = 42
tgt_col = ['quality']
# For first 
feat_col = wine_df.columns[:-1]

# 1, -1 is perfect positive, negative respectively correlation
# 0 is no correlation

# Compute correlation matrix
corr = wine_df[feat_col].corr()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap and correct aspect ratio
heatmap = sns.heatmap(corr, cmap=cmap, vmax=.3, center=0, annot=True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# # Distribution and outliers
#
# ## Distributions
# ▶ Citric acid, sulfure and alcohol are skewed distributions.
#
# We won't perform operation to normalize the data and will skip the statistical tests.

# %%
fig, axs = plt.subplots(4,3, figsize=(7,7))
axs = axs.flatten()
for i, feat in enumerate(wine_df.columns):
    sns.histplot(x=feat, ax=axs[i], data=wine_df)
plt.tight_layout()

# %%
fig, axs = plt.subplots(4,3, figsize=(10,10))
axs = axs.flatten()
for i, feat in enumerate(wine_df.columns):
    sns.boxplot(y=feat, ax=axs[i], data=wine_df, x='quality')
plt.tight_layout()

# %% [markdown]
# # Data engineering
#
# ##### Removing outliers helps to see clearly the distribution and how a feature influence the target.

# %%
# We remove the outliers from our analysis
wine_df = remove_outlier(wine_df, feat_col)
fig, axs = plt.subplots(4,3, figsize=(10,10))
axs = axs.flatten()
for i, feat in enumerate(wine_df.columns):
    sns.boxplot(y=feat, ax=axs[i], data=wine_df, x='quality')
plt.tight_layout()

# %% [markdown]
# ## Conclusion for EDA
# #### Quality prediction will be challenging. Even binarized, the dataset is very imbalanced, the predictors are correlated and overlap for different quality.
#
#
# #### Because of their high correlation with other features and low correlation with quality, think about removing:
# - free or total sulfure (later significance result will make us remove total sulfure)
# - residual sugar.
# - fixed acidity

# %% [markdown]
# ## Preparing the datasets for prediction
#
# #### We create train (70%), validation (12%) and test dataset (18%).
#
# The dataset is stratified to keep the original class distribution in all the sets.
#
# We standardize the features with a scaler.
#
# ## Preparing the subsets
#
# We will compare different subsets:
# - total (all features) dataset
# - preselect dataset from EDA, we remove
#     - *residual sugar*
#     - *free sulfure*
#     - *fixed acidity*
#     - *pH*
# - pca (7 embedded features) dataset
# - SMOTE oversampled dataset
#     - we keep all features but add more minority samples.
#
# ``ML importance subset`` is created given the features importance in LR and RF.

# %%
# Later analysis let us keep these feature
preselect = [ 'volatile_acidity', 'citric_acid',
       'chlorides', 'total_sulfur_dioxide', 'density',
       'sulphates', 'alcohol']

# Creation of train, val, test set from all feature dataset.
X_train_sc, X_val_sc, X_test_sc, y_train, y_val, y_test, scaler = create_sets(wine_df, feat_col, tgt_col)
X_train_sc_pre, X_val_sc_pre, X_test_sc_pre, y_train, y_val, y_test, scaler = create_sets(wine_df, preselect, tgt_col)
# Out:
# Train shape: (861, 11), validation shape: (153, 11), test shape: (180, 11)
# Train shape: (861, 7), validation shape: (153, 7), test shape: (180, 7)

# %% [markdown]
# ## PCA
#
#
# ### We look for the number of components enough to explain 90% of the variance.
#
# The elbow shape is unclear, but **six components** seems enough.
#
# We could try LDA as well.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.9) 
results = pca.fit(X_train_sc) 
plt.plot(np.cumsum(pca.explained_variance_ratio_))
X_train_pca = pca.transform(X_train_sc)
X_val_pca = pca.transform(X_val_sc)
X_test_pca = pca.transform(X_test_sc)

plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# # Oversampling

# %%
# We oversample with smote algorithm
oversample = SMOTE(k_neighbors=5)
X_train_os, y_train_os = oversample.fit_resample(X_train_sc, y_train)

for i in np.unique(y_train):
    per_os = 100 * np.sum(np.array([y_train_os==i]).astype(np.int32))/ len(y_train_os)
    per = 100 * np.sum(np.array([y_train==i]).astype(np.int32))/ len(y_train)
    print(f'Class {i}, {per:.2f}% -> {per_os:.2f}')
# Out:
# Class 0, 87.69% -> 50.00
# Class 1, 12.31% -> 50.00

# %% [markdown]
# # I. Linear regression
#
# We can use linear regression because the binary variable has a continuous meaning (0 < 1).
#
# ### Takeaways:
#
# ▶ R^2 is almost twice as big as multiclass model.
#
# ▶ Binary classification has higher performances than multiclass model.

# %%
# LR and check the statistical significance (since our tgt distribution is normal)
# Create linear regression object

regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train_sc, y_train)
train_pred = np.rint(regr.predict(X_train_sc))
# Make predictions using the testing set
test_pred = np.rint(regr.predict(X_test_sc))

print(f'R^2 score is {regr.score(X_train_sc, y_train):.2f}')

print('Classification result on training:')
print(classification_report(y_train, train_pred))
print('Classification result on test:')
print(classification_report(y_test, test_pred))
# Out:
# R^2 score is 0.26
# Classification result on training:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       755
#            1       0.89      0.15      0.26       106
#
#     accuracy                           0.89       861
#    macro avg       0.89      0.57      0.60       861
# weighted avg       0.89      0.89      0.86       861
#
# Classification result on test:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       158
#            1       0.33      0.05      0.08        22
#
#     accuracy                           0.87       180
#    macro avg       0.61      0.52      0.51       180
# weighted avg       0.81      0.87      0.83       180

# %% [markdown]
# ### Storing results

# %%
# Append results for linear regression fit on each dataset 
res_list = add_cls_res('linreg', regr, X_train_sc, y_train, X_test_sc, y_test,
                X_train_os, y_train_os, X_train_sc_pre, 
                X_test_sc_pre, X_train_pca, X_test_pca)

results_df = results_df.append(res_list)
print('Linear regression done')
# Out:
# --> All
# Training acc: 0.26
# Test acc: 0.21
# Roc AUC score 0.88
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       158
#            1       0.33      0.05      0.08        22
#
#     accuracy                           0.87       180
#    macro avg       0.61      0.52      0.51       180
# weighted avg       0.81      0.87      0.83       180
#
# --> Oversample
# Training acc: 0.48
# Test acc: -0.43
# Roc AUC score 0.87
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.98      0.75      0.85       158
#            1       0.33      0.91      0.49        22
#
#     accuracy                           0.77       180
#    macro avg       0.66      0.83      0.67       180
# weighted avg       0.90      0.77      0.80       180
#
# --> Preselected
# Training acc: 0.25
# Test acc: 0.21
# Roc AUC score 0.88
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       158
#            1       0.50      0.05      0.08        22
#
#     accuracy                           0.88       180
#    macro avg       0.69      0.52      0.51       180
# weighted avg       0.84      0.88      0.83       180
#
# --> PCA
# Training acc: 0.26
# Test acc: 0.21
# Roc AUC score 0.89
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       158
#            1       0.50      0.05      0.08        22
#
#     accuracy                           0.88       180
#    macro avg       0.69      0.52      0.51       180
# weighted avg       0.84      0.88      0.83       180
#
# Linear regression done

# %% [markdown]
# # II. Multiclass classification
#
# We will try and compare several model on test dataset.
#
# ##  1. Logistic regression
#
# We compute OneVersusRest binary multiclassification.
#
# ▶ Accuracy on test dataset is 0.52 with hyperparameters: C=0.1.
# ▶ Accuracy is higher without resampling, results are better without weightening.
# ▶ Logistic Regression is better of 7% than the dummy classifier.

# %% [markdown]
# ### Feature selection
#
# We use L1 regulatization to remove easily the predictors with the less effect on the accuracy.
#
# We can observe the weights for each feature in Logistic Regression.
#
# When we consider all the features, the weight associated with residual sugar and pH are almost null (they are actually removed from the feature selection).
#
# When we consider only the pre-selected subset of features, sulfure features' weight are almost null.'
#
# The most important features relatively to the weights are not the same than Linear Regression. pH and total sulfure have very important weights.
#
# ### Hyperparameter selection
#
# The best validation accuracy for a small C (inverse of regularization strenght) is obtained with C=0.01.

# %%
fig, ax = plt.subplots()


param_range = np.arange(-4., 6.)
weights, params, train_acc, val_acc = [], [], [], []
for c in param_range:
    lr = LogisticRegression(penalty='l1', C=10.**c, solver='liblinear', random_state=RANDOM_STATE)
    lr.fit(X_train_sc, y_train)
    weights.append(lr.coef_[0])
    params.append(10**c)
    train_acc.append(lr.score(X_train_sc, y_train))
    val_acc.append(lr.score(X_val_sc, y_val))

# Weight curve
weights = np.array(weights)
for column, color in zip(range(weights.shape[1]), colors):
    plt.plot(params, weights[:, column],
             label=wine_df.columns[column + 1],
             color=color)

plt.axhline(0, color='black', linestyle='--', linewidth=3)
plt.xlim([10**(-5), 10**5])
plt.ylabel('weight coefficient')
plt.xlabel('C')
plt.xscale('log')
plt.legend(loc='upper left')
ax.legend(loc='upper center', 
          bbox_to_anchor=(1.38, 1.03),
          ncol=1, fancybox=True)
plt.show()


# Validation curve
plt.plot(param_range, train_acc, 
         color='blue', marker='o', 
         markersize=5, label='Training accuracy')
plt.plot(param_range, val_acc, 
         color='blue', linestyle='--', 
         marker='s',
         markersize=5, label='Validation accuracy')
plt.legend()

# %% [markdown]
# ### Feature selection (LR)
# We remove
# - residual sugar
# - chlorides
#
# have small weights with L1 regularization.

# %%
from sklearn.linear_model import LogisticRegression
from evaluate import evaluate_cls

# C is hyperparameter to control the regularization effect
# increase, decreasing it will make the regularization strong, weaker respectively
lr = LogisticRegression(penalty='l1', C=10.**1, solver='liblinear', random_state=RANDOM_STATE,
                       )
lr.fit(X_train_sc, y_train)

evaluate_cls(lr, np.vstack([X_train_sc, X_val_sc]), np.concatenate([y_train, y_val]), X_test_sc, y_test, verbose='minimal')

print('Linear regression done')
# Out:
# Training acc: 0.91
# Test acc: 0.88
# Roc AUC score 0.64
# Precision-Recall AUC score 0.71
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       158
#            1       0.54      0.32      0.40        22
#
#     accuracy                           0.88       180
#    macro avg       0.72      0.64      0.67       180
# weighted avg       0.86      0.88      0.87       180
#
# Linear regression done

# %% [markdown]
# ### Storing results

# %%
# Append results for linear regression fit on each dataset 
res_list = add_cls_res('lr', lr, X_train_sc, y_train, X_test_sc, y_test,
                X_train_os, y_train_os, X_train_sc_pre, 
                X_test_sc_pre, X_train_pca, X_test_pca)

results_df = results_df.append(res_list)
print('Logistic regression done')
# Out:
# --> All
# Training acc: 0.91
# Test acc: 0.88
# Roc AUC score 0.64
# Precision-Recall AUC score 0.71
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       158
#            1       0.54      0.32      0.40        22
#
#     accuracy                           0.88       180
#    macro avg       0.72      0.64      0.67       180
# weighted avg       0.86      0.88      0.87       180
#
# --> Oversample
# Training acc: 0.82
# Test acc: 0.76
# Roc AUC score 0.80
# Precision-Recall AUC score 0.72
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84       158
#            1       0.32      0.86      0.46        22
#
#     accuracy                           0.76       180
#    macro avg       0.65      0.80      0.65       180
# weighted avg       0.89      0.76      0.80       180
#
# --> Preselected
# Training acc: 0.90
# Test acc: 0.88
# Roc AUC score 0.62
# Precision-Recall AUC score 0.71
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       158
#            1       0.55      0.27      0.36        22
#
#     accuracy                           0.88       180
#    macro avg       0.73      0.62      0.65       180
# weighted avg       0.86      0.88      0.87       180
#
# --> PCA
# Training acc: 0.91
# Test acc: 0.88
# Roc AUC score 0.66
# Precision-Recall AUC score 0.71
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.93       158
#            1       0.53      0.36      0.43        22
#
#     accuracy                           0.88       180
#    macro avg       0.72      0.66      0.68       180
# weighted avg       0.87      0.88      0.87       180
#
# Logistic regression done

# %% [markdown]
# ## 2. Random Forest
#
# We use a random forest classifier. Random forest uses ensemble model to gather votes from different DecisionTree and assign to each sample the class with most votes.
#
# #### Random Forest achieves the best results of this notebooks.

# %%
from sklearn.ensemble import RandomForestClassifier

# Feature importance given the average impurity decrease in the 500 decision trees. 
forest = RandomForestClassifier(n_estimators=300,
                                random_state=RANDOM_STATE)
forest.fit(X_train_sc, y_train)
evaluate_cls(forest, X_train_sc, y_train, X_test_sc, y_test, verbose='maximal')
# Out:
# Training acc: 1.00
# Test acc: 0.91
# Roc AUC score 0.71
# Precision-Recall AUC score 0.83
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       158
#            1       0.67      0.45      0.54        22
#
#     accuracy                           0.91       180
#    macro avg       0.80      0.71      0.74       180
# weighted avg       0.90      0.91      0.90       180
#
# Cross validation score with roc_auc 0.91
# [0.7969696969696969,
#  0.7114499424626007,
#  0.7439544807965861,
#  0.8954208754208753,
#  0.9055555555555556,
#  0.8976450134344873,
#  0.7114499424626008,
#  0.8276632054604702]

# %% [markdown]
# ### Hyperparameter search
#
# 300 decision trees give the best result.

# %%
from sklearn.metrics import f1_score
f1_list = {}
for _ in range(5):
    for i in tqdm(range(100, 1500, 100)):
        forest = RandomForestClassifier(n_estimators=i,
                                        random_state=RANDOM_STATE)
        forest.fit(X_train_sc, y_train)
        if i in f1_list:
            f1_list[i].append(f1_score(y_val, forest.predict(X_val_sc), average='weighted'))
        else: 
            f1_list[i] = [f1_score(y_val, forest.predict(X_val_sc), average='weighted')]
        
for t in f1_list:
    f1_list[t] = np.mean(f1_list[t])
plt.plot(list(f1_list.keys()), list(f1_list.values()))
plt.title('F1 score for different nb estimators')
# Out:
# 100%|██████████| 14/14 [00:16<00:00,  1.16s/it]
# 100%|██████████| 14/14 [00:16<00:00,  1.16s/it]
# 100%|██████████| 14/14 [00:16<00:00,  1.15s/it]
# 100%|██████████| 14/14 [00:16<00:00,  1.20s/it]
# 100%|██████████| 14/14 [00:16<00:00,  1.17s/it]
# Text(0.5, 1.0, 'F1 score for different nb estimators')

# %% [markdown]
# ### Feature importance with RandomForest
#
# ▶ The features with less importance we previously found ('residual sugar' and 'free sulfur') are again at the bottom the of feature hierarchy.
#
# ▶ Alchohol and sulphates are contributing the most.

# %%
# we save feature importance
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]

for f in range(X_train_sc.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, 
                            feat_col[indices[f]], 
                            importances[indices[f]]))

plt.title('Feature Importance')
plt.bar(range(X_train_sc.shape[1]), 
        importances[indices],
        align='center')

plt.xticks(range(X_train_sc.shape[1]), 
           feat_col[indices], rotation=90)
plt.xlim([-1, X_train_sc.shape[1]])
plt.tight_layout()
#plt.savefig('images/04_09.png', dpi=300)
plt.show()
# Out:
#  1) alcohol                        0.170136
#  2) sulphates                      0.124854
#  3) volatile_acidity               0.099358
#  4) density                        0.095878
#  5) citric_acid                    0.093249
#  6) total_sulfur_dioxide           0.078461
#  7) chlorides                      0.073275
#  8) fixed_acidity                  0.069687
#  9) pH                             0.069687
# 10) free_sulfur_dioxide            0.065583
# 11) residual_sugar                 0.059832

# %% [markdown]
# ### Storing results

# %%
# Append results for random forest fit on each dataset 
res_list = add_cls_res('rf', forest, X_train_sc, y_train, X_test_sc, y_test,
                X_train_os, y_train_os, X_train_sc_pre, 
                X_test_sc_pre, X_train_pca, X_test_pca)

results_df = results_df.append(res_list)
print('Random forest done')
# Out:
# --> All
# Training acc: 1.00
# Test acc: 0.91
# Roc AUC score 0.71
# Precision-Recall AUC score 0.83
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       158
#            1       0.67      0.45      0.54        22
#
#     accuracy                           0.91       180
#    macro avg       0.80      0.71      0.74       180
# weighted avg       0.90      0.91      0.90       180
#
# --> Oversample
# Training acc: 1.00
# Test acc: 0.88
# Roc AUC score 0.83
# Precision-Recall AUC score 0.85
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       158
#            1       0.50      0.77      0.61        22
#
#     accuracy                           0.88       180
#    macro avg       0.73      0.83      0.77       180
# weighted avg       0.91      0.88      0.89       180
#
# --> Preselected
# Training acc: 1.00
# Test acc: 0.92
# Roc AUC score 0.72
# Precision-Recall AUC score 0.84
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       158
#            1       0.77      0.45      0.57        22
#
#     accuracy                           0.92       180
#    macro avg       0.85      0.72      0.76       180
# weighted avg       0.91      0.92      0.91       180
#
# --> PCA
# Training acc: 1.00
# Test acc: 0.91
# Roc AUC score 0.71
# Precision-Recall AUC score 0.81
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       158
#            1       0.71      0.45      0.56        22
#
#     accuracy                           0.91       180
#    macro avg       0.82      0.71      0.75       180
# weighted avg       0.90      0.91      0.90       180
#
# Random forest done

# %% [markdown]
# ### ROC and PR curves
#
# Since RF is the highest score classifier, we take the time to look at its predictability power.
#
# #### Precision Recall
# Precision-Recall curve are more appropriate than ROC curve when the classes are imbalanced.
# With PR curve, we can observe the decrease of performances to detect class the good wines.

# %%
forest.fit(X_train_sc, y_train)
plot_roc_pr_curves(forest, X_test_sc, y_test)

# %% [markdown]
# ## 3. SVM
#
# Support Vector Machine are effective in high dimension space.
#
# Results are disappointing for linear SVC, the results only detect two classes.

# %%
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import f1_score, make_scorer

# # We could try 'rbf' and 'poly' kernel but the CV would not end on my local computer.
labels = np.unique(wine_df[tgt_col].values)
# parameters = {
#     'kernel': ['linear'],
#     'C': [0.001, 0.01, 0.1, 1, 2, 5, 10],
#     'gamma': [0.01, 0.1, 0.5, 1]
# }
# grid_parameters = list(ParameterGrid(parameters))
# print('Start GridSearch among', len(grid_parameters), 'possibilities')
# svc = GridSearchCV(SVC(), parameters, n_jobs=-1, verbose=0, scoring=make_scorer(f1_score, average='weighted'))
# print('param', svc.best_params_)

best_params = {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
svc = SVC(**best_params)
svc.fit(X_train_sc, y_train)

# Normal dataset
evaluate_cls(svc, X_train_sc, y_train, X_test_sc, y_test, verbose='minimal')
# Out:
# Training acc: 0.91
# Test acc: 0.88
# Roc AUC score 0.60
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94       158
#            1       0.56      0.23      0.32        22
#
#     accuracy                           0.88       180
#    macro avg       0.73      0.60      0.63       180
# weighted avg       0.86      0.88      0.86       180
# [0.7280701754385965,
#  0.6009781357882623,
#  0.6293754289636239,
#  0.8584145549057829,
#  0.8833333333333333,
#  0.8611759322809424,
#  None,
#  None]

# %% [markdown]
# ### Storing results

# %%
# Append results for SVM fit on each dataset 
res_list = add_cls_res('svm', svc, X_train_sc, y_train, X_test_sc, y_test,
                X_train_os, y_train_os, X_train_sc_pre, 
                X_test_sc_pre, X_train_pca, X_test_pca)

results_df = results_df.append(res_list)
print('SVM done')
# Out:
# --> All
# Training acc: 0.91
# Test acc: 0.88
# Roc AUC score 0.60
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94       158
#            1       0.56      0.23      0.32        22
#
#     accuracy                           0.88       180
#    macro avg       0.73      0.60      0.63       180
# weighted avg       0.86      0.88      0.86       180
#
# --> Oversample
# Training acc: 0.82
# Test acc: 0.74
# Roc AUC score 0.80
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.97      0.73      0.83       158
#            1       0.31      0.86      0.45        22
#
#     accuracy                           0.74       180
#    macro avg       0.64      0.80      0.64       180
# weighted avg       0.89      0.74      0.79       180
#
# --> Preselected
# Training acc: 0.88
# Test acc: 0.88
# Roc AUC score 0.50
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93       158
#            1       1.00      0.00      0.00        22
#
#     accuracy                           0.88       180
#    macro avg       0.94      0.50      0.47       180
# weighted avg       0.89      0.88      0.82       180
#
# --> PCA
# Training acc: 0.91
# Test acc: 0.88
# Roc AUC score 0.58
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       158
#            1       0.50      0.18      0.27        22
#
#     accuracy                           0.88       180
#    macro avg       0.70      0.58      0.60       180
# weighted avg       0.85      0.88      0.85       180
#
# SVM done

# %% [markdown]
# ## 4. MLP
#
# We find the best hyperparameters (out of this notebook):
#
# Like Random Forest the model overfits but test accuracy is good.
#
# Performances are slighlty less than Random Forest.

# %% [markdown]
# ### Hyperparameter search
#
# (actually done offline)

# %%
# from sklearn.neural_network import MLPClassifier

# grid_parameters = {
#         'hidden_layer_sizes': [(50,50), (100,50), (500,15), (100,)],
#         'activation': ['tanh', 'relu'],
#         'solver': ['sgd', 'adam'],
#         'alpha': 10.0 ** -np.arange(1, 10),
#         'learning_rate': ['adaptive'],
#         'max_iter': [5000]
#         }
# clf = GridSearchCV(MLPClassifier(random_state=RANDOM_STATE), grid_parameters, n_jobs=-1, verbose=1)
# clf.fit(X_train_sc, y_train)

# %% [markdown]
# ### Fitting the model with best parameters

# %%
import joblib 

# We import the results
cv_res = joblib.load('../mlp_red_cv.pkl')
print(cv_res.best_params_)

best_params = {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (500, 15), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'sgd'}
clf = MLPClassifier(random_state=RANDOM_STATE, **best_params)

clf.fit(X_train_sc, y_train)
evaluate_cls(clf, X_train_sc, y_train, X_test_sc, y_test, verbose='maximal')
# Out:
# {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (500, 15), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'sgd'}
# Training acc: 0.91
# Test acc: 0.85
# Roc AUC score 0.58
# Precision-Recall AUC score 0.72
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       158
#            1       0.33      0.23      0.27        22
#
#     accuracy                           0.85       180
#    macro avg       0.62      0.58      0.59       180
# weighted avg       0.83      0.85      0.84       180
#
# Cross validation score with roc_auc 0.90
# [0.6151515151515151,
#  0.5819907940161104,
#  0.5933394695004601,
#  0.8280808080808081,
#  0.85,
#  0.8374361978077147,
#  0.5819907940161105,
#  0.7221886244558811]

# %% [markdown]
# ### Storing results

# %%
# Append results for MLP fit on each dataset 
res_list = add_cls_res('mlp', svc, X_train_sc, y_train, X_test_sc, y_test,
                X_train_os, y_train_os, X_train_sc_pre, 
                X_test_sc_pre, X_train_pca, X_test_pca)

results_df = results_df.append(res_list)
print('MLP done')
# Out:
# --> All
# Training acc: 0.91
# Test acc: 0.88
# Roc AUC score 0.60
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94       158
#            1       0.56      0.23      0.32        22
#
#     accuracy                           0.88       180
#    macro avg       0.73      0.60      0.63       180
# weighted avg       0.86      0.88      0.86       180
#
# --> Oversample
# Training acc: 0.82
# Test acc: 0.74
# Roc AUC score 0.80
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.97      0.73      0.83       158
#            1       0.31      0.86      0.45        22
#
#     accuracy                           0.74       180
#    macro avg       0.64      0.80      0.64       180
# weighted avg       0.89      0.74      0.79       180
#
# --> Preselected
# Training acc: 0.88
# Test acc: 0.88
# Roc AUC score 0.50
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93       158
#            1       1.00      0.00      0.00        22
#
#     accuracy                           0.88       180
#    macro avg       0.94      0.50      0.47       180
# weighted avg       0.89      0.88      0.82       180
#
# --> PCA
# Training acc: 0.91
# Test acc: 0.88
# Roc AUC score 0.58
# AUC non available
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       158
#            1       0.50      0.18      0.27        22
#
#     accuracy                           0.88       180
#    macro avg       0.70      0.58      0.60       180
# weighted avg       0.85      0.88      0.85       180
#
# MLP done

# %% [markdown]
# ## 5. XGBoost
#
# Performances similar with RF.

# %%
import xgboost as xgb

xgb_ = xgb.XGBClassifier(random_state=RANDOM_STATE)
xgb_.fit(X_train_sc, y_train)
val_pred = xgb_.predict(X_val_sc)
evaluate_cls(xgb_, X_train_sc, y_train, X_test_sc, y_test, verbose='minimal')
# Out:
# [21:27:19] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/bettyld/anaconda3/envs/netsmile/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Training acc: 1.00
# Test acc: 0.88
# Roc AUC score 0.74
# Precision-Recall AUC score 0.79
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       158
#            1       0.52      0.55      0.53        22
#
#     accuracy                           0.88       180
#    macro avg       0.73      0.74      0.73       180
# weighted avg       0.89      0.88      0.88       180
# <AxesSubplot:>

# %% [markdown]
# ### Features importance
# Due to the high performances of XGBoost (very slighly under RF), we check at the most important features.

# %%
feat_importances = pd.Series(xgb_.feature_importances_, index=feat_col)
feat_importances.nlargest(5).plot(kind='barh',figsize=(10,10))

# %% [markdown]
# ### Storing results

# %%
# Append results for XGBoost fit on each dataset 
res_list = add_cls_res('xgboost', xgb_, X_train_sc, y_train, X_test_sc, y_test,
                X_train_os, y_train_os, X_train_sc_pre, 
                X_test_sc_pre, X_train_pca, X_test_pca)
results_df = results_df.append(res_list)
print('XGBoost done')
# Out:
# --> All
# [21:27:20] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/bettyld/anaconda3/envs/netsmile/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Training acc: 1.00
# Test acc: 0.88
# Roc AUC score 0.74
# Precision-Recall AUC score 0.79
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       158
#            1       0.52      0.55      0.53        22
#
#     accuracy                           0.88       180
#    macro avg       0.73      0.74      0.73       180
# weighted avg       0.89      0.88      0.88       180
#
# --> Oversample
# [21:27:20] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training acc: 1.00
# Test acc: 0.86
# Roc AUC score 0.74
# Precision-Recall AUC score 0.76
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92       158
#            1       0.45      0.59      0.51        22
#
#     accuracy                           0.86       180
#    macro avg       0.69      0.74      0.71       180
# weighted avg       0.88      0.86      0.87       180
#
# --> Preselected
# [21:27:20] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/bettyld/anaconda3/envs/netsmile/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/bettyld/anaconda3/envs/netsmile/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Training acc: 1.00
# Test acc: 0.89
# Roc AUC score 0.71
# Precision-Recall AUC score 0.78
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       158
#            1       0.59      0.45      0.51        22
#
#     accuracy                           0.89       180
#    macro avg       0.76      0.71      0.73       180
# weighted avg       0.89      0.89      0.89       180
#
# --> PCA
# [21:27:21] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Training acc: 1.00
# Test acc: 0.89
# Roc AUC score 0.71
# Precision-Recall AUC score 0.74
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       158
#            1       0.59      0.45      0.51        22
#
#     accuracy                           0.89       180
#    macro avg       0.76      0.71      0.73       180
# weighted avg       0.89      0.89      0.89       180
#
# XGBoost done
# /home/bettyld/anaconda3/envs/netsmile/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %% [markdown]
# # Conclusion
#
# #### Binary classification has significantly higher performances than multiclass classification.
#
# ### A) Best binary classifiers:
#
# |  Model |  Dataset | F1-macro % |  F1-weighted % | Precision-m % | Recall-m % |
# |---|---|---|---|---|---|
# | **Random Forest** | oversample| 78.8  | 89.8  | 75.1  | 85.8  |
# | **XGBoost** | oversample| 75.3  | 88.5  | 72.6  | 79.3  |
#
# **Random forest has the highest results.**
#
# ### B) Best datasets:
# - The ``preselected features`` dataset has highest results on weighted score. But it has worst macro recall and f1 score.
# - The ``oversampling`` dataset has highest results on macro scores.
# - The ``all features`` dataset is robust (good performances on all models)
#
# ``Oversample`` actually increases significantly the recall of good wine but also decrease the precision. The recall increase is so important that on macro-average speaking the F1 score is higher than without. We should avoid using it if we want a high precision.
#
# We could have used ``all features``, but if the dataset if big, using ``preselected feature`` avoid overfitting and provide good performances.
#
# **According to the desired performances (precision, recall, detecting good wines more important than worse wine), we should choose a dataset accordingly.**
#
# ### C) Best features:
# - Alcohol is positively correlated with the wine quality.
# - Sulphates is negatively correlated with the wone quality.
#
# ### D) Removable features:
# - *residual sugar*
# - *free sulfure*
# - *fixed acidity*
# - *pH*

# %%
# *_m is macro average
# *_w is weighted average
# auc is Area Under the Curve
# PR is Precision-Recall area

# Overview of the results
results_df.sort_values(by=['f1_m', 'f1_w', 'pr'], ascending=False)
# Out:
#     method dataset      pr_m     rec_m      f1_m      pr_w     rec_w  \
# 1       rf      os  0.732877  0.832566  0.767387  0.908828  0.877778
# 2       rf     pre  0.848687  0.717779  0.762637  0.908721  0.916667
# 3       rf     pca  0.820998  0.714614  0.753086  0.901626  0.911111
# 0       rf     all  0.796970  0.711450  0.743954  0.895421  0.905556
# 0  xgboost     all  0.729022  0.737917  0.733333  0.885636  0.883333
# 2  xgboost     pre  0.757308  0.705121  0.726815  0.885052  0.894444
# 3  xgboost     pca  0.757308  0.705121  0.726815  0.885052  0.894444
# 1  xgboost      os  0.694337  0.744822  0.714449  0.880249  0.861111
# 3       lr     pca  0.724242  0.659666  0.683708  0.868485  0.883333
# 1   linreg      os  0.658333  0.827963  0.668363  0.903889  0.766667
# 0       lr     all  0.724321  0.640104  0.667692  0.864747  0.883333
# 1       lr      os  0.645833  0.802071  0.652571  0.894537  0.755556
# 2       lr     pre  0.725390  0.620541  0.649708  0.861341  0.883333
# 1      svm      os  0.640514  0.795742  0.642857  0.892917  0.744444
# 1      mlp      os  0.640514  0.795742  0.642857  0.892917  0.744444
# 0      svm     all  0.728070  0.600978  0.629375  0.858415  0.883333
# 0      mlp     all  0.728070  0.600978  0.629375  0.858415  0.883333
# 3      svm     pca  0.697674  0.578251  0.600000  0.847028  0.877778
# 3      mlp     pca  0.697674  0.578251  0.600000  0.847028  0.877778
# 2   linreg     pre  0.691011  0.519563  0.508929  0.835331  0.877778
# 3   linreg     pca  0.691011  0.519563  0.508929  0.835331  0.877778
# 0   linreg     all  0.607345  0.516398  0.505672  0.814375  0.872222
# 2      svm     pre  0.938889  0.500000  0.467456  0.892716  0.877778
# 2      mlp     pre  0.938889  0.500000  0.467456  0.892716  0.877778
#
#        f1_w       auc        pr
# 1  0.888461  0.832566  0.851717
# 2  0.907106  0.717779  0.842943
# 3  0.902332  0.714614  0.805385
# 0  0.897645   0.71145  0.827663
# 0  0.884444  0.737917  0.786877
# 2  0.888500  0.705121  0.781768
# 3  0.888500  0.705121  0.744362
# 1  0.869070  0.744822  0.756128
# 3  0.873561  0.659666  0.706708
# 1  0.804784      None      None
# 0  0.869949  0.640104  0.705316
# 1  0.795488  0.802071    0.7189
# 2  0.865851  0.620541  0.713133
# 1  0.786772      None      None
# 1  0.786772      None      None
# 0  0.861176      None      None
# 0  0.861176      None      None
# 3  0.851852      None      None
# 3  0.851852      None      None
# 2  0.830489      None      None
# 3  0.830489      None      None
# 0  0.827290      None      None
# 2  0.820644      None      None
# 2  0.820644      None      None

# %%
sns.barplot(x='method', y='f1_m', data=results_df, hue='dataset')
plt.title('Models/Datasets by F1 macro score')
# Out:
# Text(0.5, 1.0, 'Models/Datasets by F1 macro score')

# %%
sns.barplot(x='method', y='f1_w', data=results_df, hue='dataset')
plt.title('Models/Datasets by F1 weighted score')
# Out:
# Text(0.5, 1.0, 'Models/Datasets by F1 weighted score')

# %%
# Average result of each dataset on each metric
results_df.groupby('dataset').mean()
# Out:
#              pr_m     rec_m      f1_m      pr_w     rec_w      f1_w
# dataset
# all      0.718966  0.634638  0.651567  0.862835  0.885185  0.866947
# os       0.668735  0.799818  0.681414  0.895556  0.791667  0.821891
# pca      0.731485  0.625911  0.645423  0.864092  0.887037  0.866431
# pre      0.816696  0.593834  0.597167  0.879313  0.887963  0.855539
